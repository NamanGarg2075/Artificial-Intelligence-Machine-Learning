# %% [markdown]
# # Simple Linear Regression
# ![image](https://raw.githubusercontent.com/codebasics/py/801ee0ee4d342fd22b89915dc0c4864250a0ec10/ML/1_linear_reg/linear_equation.png)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('Data/homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'],df['price'],color='red',marker='+')
plt.xlabel('Area')
plt.ylabel('Price (US$)')
# Out:
# Text(0, 0.5, 'Price (US$)')

# %%
new_df = df[['area']]
price = df['price']

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
reg.predict([[2600]])
# Out:
# c:\Users\naman\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %%
# verifying answer ()
reg.coef_ * 3300 + reg.intercept_
# Out:
# array([628715.75342466])

# %%
plt.xlabel('Area')
plt.ylabel('Price (US$)')
plt.scatter(df['area'],df['price'],color='red',marker='+')
plt.plot(df['area'],reg.predict(df[['area']]),color='blue')
